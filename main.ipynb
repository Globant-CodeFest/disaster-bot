# %% [markdown]
# # Hackaton

# %%
import folium
import json
import pandas as pd 
import geopandas as gpd
from shapely.geometry import Point
from gpt import parse_data, get_insights_of_disasters, get_insights_of_disasters_and_hospitals
from helpers.get_geojson import get_geojson
from helpers.polygons import is_inside

# %%
from IPython.display import display, HTML

def nice_print(string):
  html_string = ""
  string_array = string.split(' ')
  for i in range(0, len(string_array), 16):
    string_line = " ".join(string_array[i: i + 16])
    html_string += f'<p style="font-size: 16px";>{string_line}</p>\n'
  display(HTML(html_string))

# %% [markdown]
# ## Load data

# %%
disasters_df = gpd.read_file('data/distasters_parsed.geojson')
hospitals_df = pd.read_csv('data/centros_salud_filtered_urgencia.csv')

# %%
disasters_df['Disaster Type'] = disasters_df['Disaster Type'].replace({"Flood": "Inundacion",
                                          "Volcanic activity": "Volcan",
                                          "Storm": "Tormenta",
                                          "Earthquake": "Terremoto",
                                          "Landslide": "Aluvion",
                                          "Wildfire": "Incendio"})

# %% [markdown]
# ## Main Loop
#
# - read input
# - parse to structured
# - get geojson
# - filter type
# - show data

# %%
disasters_df.head()
# Out:
#    Year   Seq Glide Disaster Group Disaster Subgroup Disaster Type  \
# 0  1964    17   NaN        Natural       Geophysical        Volcan
# 1  1965    40   NaN        Natural      Hydrological    Inundacion
# 2  1968  9008   NaN        Natural    Climatological       Drought
# 3  1968    57   NaN        Natural    Meteorological      Tormenta
# 4  1974    27   NaN        Natural      Hydrological    Inundacion
#
#   Disaster Subtype Disaster Subsubtype Event Name Country  ... No Homeless  \
# 0         Ash fall                 NaN        NaN   Chile  ...         NaN
# 1              NaN                 NaN        NaN   Chile  ...     25000.0
# 2          Drought                 NaN        NaN   Chile  ...         NaN
# 3              NaN                 NaN        NaN   Chile  ...         NaN
# 4              NaN                 NaN        NaN   Chile  ...         NaN
#
#   Total Affected Insured Damages ('000 US$) Total Damages ('000 US$)  \
# 0         2000.0                        NaN                      NaN
# 1       375000.0                        NaN                  10000.0
# 2       120000.0                        NaN                  55000.0
# 3            NaN                        NaN                      NaN
# 4        40000.0                        NaN                  10000.0
#
#          CPI Adm Level Admin1 Code Admin2 Code Geo Locations  \
# 0  11.984281       NaN         NaN         NaN           NaN
# 1  12.174253       NaN         NaN         NaN           NaN
# 2  13.439657       NaN         NaN         NaN           NaN
# 3  13.439657       NaN         NaN         NaN           NaN
# 4  19.051854       NaN         NaN         NaN           NaN
#
#                       geometry
# 0  POINT (-72.23078 -39.28201)
# 1  POINT (-70.39750 -23.65093)
# 2  POINT (-71.54297 -35.67515)
# 3  POINT (-71.54297 -35.67515)
# 4  POINT (-71.54297 -35.67515)
#
# [5 rows x 46 columns]

# %%
hospitals_df.head()
# Out:
#            X          Y  FID  codest                          nomeste  codreg  \
# 0 -70.290543 -18.437603   15  01-900  SAPU-Dr. Amador Neghme de Arica      15
# 1 -70.282444 -18.483881   16  01-901             SAPU-Iris Véliz Hume      15
# 2 -70.134674 -20.226259   34  02-800            SAPU-Cirujano Aguirre       1
# 3 -70.150170 -20.208263   35  02-801             SAPU-Cirujano Videla       1
# 4 -70.136451 -20.236900   36  02-802             SAPU-Cirujano Guzmán       1
#
#                 nomreg  codss                      nomss  codcom  ...  \
# 0  De Arica Parinacota      1    Servicio de Salud Arica   15101  ...
# 1  De Arica Parinacota      1    Servicio de Salud Arica   15101  ...
# 2          De Tarapacá      2  Servicio de Salud Iquique    1101  ...
# 3          De Tarapacá      2  Servicio de Salud Iquique    1101  ...
# 4          De Tarapacá      2  Servicio de Salud Iquique    1101  ...
#
#                                        Place certifi     depend     nivel  \
# 0  Servicio de Atencion Primaria de Urgencia     S/C  Municipal  Primario
# 1  Servicio de Atencion Primaria de Urgencia     S/C  Municipal  Primario
# 2  Servicio de Atencion Primaria de Urgencia     S/C  Municipal  Primario
# 3  Servicio de Atencion Primaria de Urgencia     S/C  Municipal  Primario
# 4  Servicio de Atencion Primaria de Urgencia     S/C  Municipal  Primario
#
#   viaacceso                    direcc  Longitude   Latitude  cod_nuevo  \
# 0   Avenida  Cancha Rayada 4149 Arica -70.290543 -18.437603     200094
# 1     Calle    Barros Luco 2269 Arica -70.282444 -18.483881     200095
# 2    Pasaje    Chintaguay S/N Iquique -70.134674 -20.226259     102800
# 3     Calle  Obispo Labbé S/N Iquique -70.150170 -20.208263     102801
# 4   Avenida  Pedro Prado 2736 Iquique -70.136451 -20.236900     102802
#
#                              Coordinates
# 0  POINT (-70.2905433131 -18.4376026272)
# 1  POINT (-70.2824436462 -18.4838808045)
# 2  POINT (-70.1346740237 -20.2262589719)
# 3   POINT (-70.150170342 -20.2082628936)
# 4  POINT (-70.1364509765 -20.2369000291)
#
# [5 rows x 22 columns]

# %%
def plot_map(disasters_filtered, hospitals_filtered):
  m = folium.Map(location=[disasters_df['Latitude'].mean(), disasters_df['Longitude'].mean()], zoom_start=6)
  latitudes, longitudes = [], []
  for i in range(0, len(disasters_filtered)):
    latitudes.append(disasters_filtered.iloc[i]['Latitude'])
    longitudes.append(disasters_filtered.iloc[i]['Longitude'])
    folium.Marker([disasters_filtered.iloc[i]['Latitude'], disasters_filtered.iloc[i]['Longitude']], icon=folium.Icon(color='red'), popup=disasters_filtered.iloc[i]['Disaster Type']).add_to(m)
  for i in range(0, len(hospitals_filtered)):
    latitudes.append(hospitals_filtered.iloc[i]['Latitude'])
    longitudes.append(hospitals_filtered.iloc[i]['Longitude'])
    folium.Marker([hospitals_filtered.iloc[i]['Latitude'], hospitals_filtered.iloc[i]['Longitude']], icon=folium.Icon(color='blue'), popup=hospitals_filtered.iloc[i]['nomeste']).add_to(m)
  min_lat = min(latitudes)
  max_lat = max(latitudes)
  min_long = min(longitudes)
  max_long = max(longitudes)
  bounds = [[min_lat, min_long], [max_lat, max_long]]
  m.fit_bounds(bounds)
  return m

# %%
def location_insights(ubicacion):
    geojson = get_geojson(ubicacion)
    boolean_filter = []
    for _, row in disasters_df.iterrows():
        is_in = False
        for _, zone in geojson.iterrows():
            if zone['geometry'].contains(row['geometry']):
                boolean_filter.append(True)
                is_in = True
                break
        if not is_in:
            boolean_filter.append(False)

    filtered_disasters = disasters_df[boolean_filter]
    if len(filtered_disasters) == 0:
        print('No hay datos en la zona:', geojson)
        return
    disasters = filtered_disasters['Disaster Type'].value_counts()
    disasters_str = ""
    for index, value in disasters.items():
        disasters_str += f"{index}: {value}\n"
    print(disasters_str)
    nice_print(get_insights_of_disasters(disasters_str, ubicacion))
    return plot_map(filtered_disasters, [])

# %%
def calculate_distance(point1, point2):
    point1 = point1.strip('POINT ').strip('(').strip(')')
    x, y = point1.split()
    x, y = float(x), float(y)
    point1 = Point(x, y)
    return point1.distance(point2)

def get_nearest_hospitals(polygon):
    center = polygon.centroid
    point = Point(center.x, center.y)
    hosp_copy = hospitals_df.copy()
    hosp_copy['Distance'] = hosp_copy['Coordinates'].apply(lambda x: calculate_distance(x, point))
    nearest_row = hosp_copy.loc[hosp_copy['Distance'].idxmin()]
    return nearest_row

# %%
from shapely.geometry import Point, Polygon

def get_location_and_assist(ubicacion):
    geojson = get_geojson(ubicacion)
    boolean_filter = []
    boolean_filter_2 = []
    for _, row in disasters_df.iterrows():
        is_in = False
        for _, zone in geojson.iterrows():
            if zone['geometry'].contains(row['geometry']):
                boolean_filter.append(True)
                is_in = True
                break
        if not is_in:
            boolean_filter.append(False)
    for _, row in hospitals_df.iterrows():
        is_in = False
        for _, zone in geojson.iterrows():
            point = Point(row['Longitude'], row['Latitude'])
            if zone['geometry'].contains(point):
                boolean_filter_2.append(True)
                is_in = True
                break
        if not is_in:
            boolean_filter_2.append(False)
    filtered_disasters = disasters_df[boolean_filter]
    filtered_hospitals = hospitals_df[boolean_filter_2]
    print('hospitales:', len(filtered_hospitals))
    if len(filtered_disasters) == 0:
        print('No hay datos en la zona:', geojson)
        return
    disasters = filtered_disasters['Disaster Type'].value_counts()
    disasters_str = ""
    total_disasters = 0
    for index, value in disasters.items():
        disasters_str += f"{index}: {value}\n"
        total_disasters += value
    if len(filtered_hospitals) == 0:
        ratio = 0
    else:
        ratio = len(filtered_hospitals) / total_disasters
    print('Ratio desastres/centros:', ratio)
    print(disasters_str)
    if len(filtered_hospitals) == 0:
        hosp = get_nearest_hospitals(geojson)
        filtered_hospitals = pd.DataFrame([hosp])
    nice_print(get_insights_of_disasters_and_hospitals(disasters_str, ubicacion, ratio))
    return plot_map(filtered_disasters, filtered_hospitals)

# %%
queries = [
  'estoy en chaiten, hablame sobre los desastres naturales y los hospitales',
  'por favor hablame sobre que peligros hay en antofagasta, y que centros asistenciales me pueden ayudar',
  'cuanto miden los gatos en promedio',
  'estoy yendo a puerto mont. de que me debería preocupar',
  'voy a punta arenas hospitales',
]

# %%
_input = queries[0]
# _input = input('Ingrese query:')
parsed_input = parse_data(_input)
print(parsed_input)
ubicacion = parsed_input['ubicacion']

# location filter

if ubicacion and parsed_input['centro_asistencial']:
    m = get_location_and_assist(ubicacion)
elif ubicacion:
    m = location_insights(ubicacion)
else:
    print('Esa no es una query valida.')
    m = None

m
# Out:
# {'ubicacion': 'punta arenas', 'tipo_de_desastre': None, 'centro_asistencial': 'hospital'}
# hospitales: 3
# Ratio desastres/centros: 0.75
# Inundacion: 2
# Incendio: 2
# <p style="font-size: 16px";>En la zona de Punta Arenas existen desastres naturales como inundaciones e incendios, los cuales pueden</p>
# <p style="font-size: 16px";>poner en riesgo la salud y la vida de las personas. El ratio desastre natural/centros asistenciales</p>
# <p style="font-size: 16px";>es de 0.75, lo que indica que se necesitan más centros asistenciales para poder atender a</p>
# <p style="font-size: 16px";>la población en caso de emergencia. Es importante tomar medidas preventivas para evitar estos desastres, como</p>
# <p style="font-size: 16px";>mantener limpios los cauces de los ríos y evitar el uso de fuego en zonas forestales.</p>
# <p style="font-size: 16px";>Además, es fundamental contar con planes de evacuación y estar preparados ante cualquier eventualidad. La prevención</p>
# <p style="font-size: 16px";>es la clave para evitar tragedias.</p>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08f2029681a1ee8e9d05b6da4ba6f664 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08f2029681a1ee8e9d05b6da4ba6f664&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08f2029681a1ee8e9d05b6da4ba6f664 = L.map(
#                 &quot;map_08f2029681a1ee8e9d05b6da4ba6f664&quot;,
#                 {
#                     center: [-33.69372640007141, -67.05419160613896],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bc983b6f592792c3efda2e5332b212d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_08f2029681a1ee8e9d05b6da4ba6f664);
#
#
#             var marker_758b371794d7f721611cfcae10565434 = L.marker(
#                 [-53.1633845, -70.9078263],
#                 {}
#             ).addTo(map_08f2029681a1ee8e9d05b6da4ba6f664);
#
#
#             var icon_170ec5df4c5290d745a07e748867f8a5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_758b371794d7f721611cfcae10565434.setIcon(icon_170ec5df4c5290d745a07e748867f8a5);
#
#
#         var popup_86caf746d28eb8ca2a51851bb9e70c1c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7fe730fc1f945876cb8714bb9f793a2 = $(`&lt;div id=&quot;html_d7fe730fc1f945876cb8714bb9f793a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Inundacion&lt;/div&gt;`)[0];
#                 popup_86caf746d28eb8ca2a51851bb9e70c1c.setContent(html_d7fe730fc1f945876cb8714bb9f793a2);
#
#
#
#         marker_758b371794d7f721611cfcae10565434.bindPopup(popup_86caf746d28eb8ca2a51851bb9e70c1c)
#         ;
#
#
#
#
#             var marker_3309217d0f290b788321bfc3c73b31e4 = L.marker(
#                 [-53.4428344, -72.1496817],
#                 {}
#             ).addTo(map_08f2029681a1ee8e9d05b6da4ba6f664);
#
#
#             var icon_fd62b5efc757acd01b0e02a846d503e9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3309217d0f290b788321bfc3c73b31e4.setIcon(icon_fd62b5efc757acd01b0e02a846d503e9);
#
#
#         var popup_4cbb918bb43adc5d056405a96d663a7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a6ae4ed8ca131ac8d8b2abd854da4162 = $(`&lt;div id=&quot;html_a6ae4ed8ca131ac8d8b2abd854da4162&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Inundacion&lt;/div&gt;`)[0];
#                 popup_4cbb918bb43adc5d056405a96d663a7b.setContent(html_a6ae4ed8ca131ac8d8b2abd854da4162);
#
#
#
#         marker_3309217d0f290b788321bfc3c73b31e4.bindPopup(popup_4cbb918bb43adc5d056405a96d663a7b)
#         ;
#
#
#
#
#             var marker_b6e1e1c15fa01a3b61b7574f8c57ea2a = L.marker(
#                 [-53.4428344, -72.1496817],
#                 {}
#             ).addTo(map_08f2029681a1ee8e9d05b6da4ba6f664);
#
#
#             var icon_a2501963ec52ae430ab4bb75c638d9b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b6e1e1c15fa01a3b61b7574f8c57ea2a.setIcon(icon_a2501963ec52ae430ab4bb75c638d9b7);
#
#
#         var popup_e1db2e143244129488a2aacf4fe7c591 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_99b325cddac4cdb16a0474d3ac65e463 = $(`&lt;div id=&quot;html_99b325cddac4cdb16a0474d3ac65e463&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Incendio&lt;/div&gt;`)[0];
#                 popup_e1db2e143244129488a2aacf4fe7c591.setContent(html_99b325cddac4cdb16a0474d3ac65e463);
#
#
#
#         marker_b6e1e1c15fa01a3b61b7574f8c57ea2a.bindPopup(popup_e1db2e143244129488a2aacf4fe7c591)
#         ;
#
#
#
#
#             var marker_60e38699f8cd1fa42edc31a577fbb942 = L.marker(
#                 [-53.4428344, -72.1496817],
#                 {}
#             ).addTo(map_08f2029681a1ee8e9d05b6da4ba6f664);
#
#
#             var icon_061546303256d7531aafb91748be43d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;i

# %%
# Load GeoJSON data
with open("data/establecimientos_salud.geojson") as f:
    geo_json_data = json.load(f)

# Add the GeoJSON layer
folium.GeoJson(geo_json_data, name='geojson').add_to(m)
